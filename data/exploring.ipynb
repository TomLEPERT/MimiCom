# %%
import pandas as pd

# %%
df = pd.read_csv("fake_festival_jdr_dataset.csv")
df.head()
# Out:
#          ID                   Nom                         Email  \
# 0  577e9231  Bar à jeux Remercier    laurentbernard@example.com
# 1  d58e5151   Bar à jeux Désigner   francoiselebrun@example.com
# 2  0aa6de42       Asso jdr Humide                           NaN
# 3  25b871e8         MJC Politique  charrierclaudine@example.org
# 4  72eb6140    Asso jdr Permettre             ubrun@example.org
#
#                     Tel        Type                 Web_site  \
# 0        02 97 06 01 93  Bar à jeux        http://coste.net/
# 1  +33 (0)1 81 27 55 14  Bar à jeux  https://www.collet.com/
# 2            0434310028    Asso jdr      https://baudry.com/
# 3            0481699735         MJC    http://www.coulon.fr/
# 4            0535315739    Asso jdr     https://mercier.net/
#
#                       FB  FB_nb_aderent                   Twitter  \
# 0  https://petitjean.fr/         1743.0        https://godard.fr/
# 1      http://gilles.fr/          938.0  https://www.ollivier.fr/
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  5000 non-null   object
#  1   Nom                 5000 non-null   object
#  2   Email               4785 non-null   object
#  3   Tel                 4481 non-null   object
#  4   Type                5000 non-null   object
#  5   Web_site            4550 non-null   object
#  6   FB                  4087 non-null   object
#  7   FB_nb_aderent       4087 non-null   float64
#  8   Twitter             3046 non-null   object
#  9   Twitter_nb_aderent  3046 non-null   float64
#  10  Insta               2750 non-null   object
#  11  Insta_nb_aderent    2750 non-null   float64
#  12  Youtube             792 non-null    object
#  13  Youtube_nb_aderent  792 non-null    float64
#  14  Tiktok              390 non-null    object
# ...
